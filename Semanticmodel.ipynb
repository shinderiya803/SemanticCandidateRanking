# %% [markdown]
# <a href="https://colab.research.google.com/github/shinderiya803/SemanticCandidateRanking/blob/main/Semanticmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eb639d9a-6677-4918-a689-7b52b5c04ad4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb639d9a-6677-4918-a689-7b52b5c04ad4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !cat semanticcandidateranking.py
# Out:
# # -*- coding: utf-8 -*-
# """SemanticCandidateRanking.ipynb
#
# Automatically generated by Colab.
#
# Original file is located at
#     https://colab.research.google.com/drive/1K1vCJI5z2Ewg5dzRSqNniylKRhNMQb4V
# """
#
# from google.colab import files # upload zipped
#
# uploaded = files.upload()
#
# import zipfile # Unzip data
#
# zip_path = "/content/[PUB] India_runs_data_and_ai_challenge.zip"
#
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall("/content/data")
# print("Dataset extracted successfully!")
#
# import os    # See the Files
#
# for root, dirs, files in os.walk("/content/data"):
#     for file in files:
#         print(os.path.join(root, file))
#
# !pip install sentence-transformers python-docx pandas scikit-learn #Install python libraries
#
# from docx import Document # Read job description
#
# doc = Document("/content/data/[PUB] India_runs_data_and_ai_challenge/India_runs_data_and_ai_challenge/job_description.docx")
#
# job_description = ""
#
# ...
